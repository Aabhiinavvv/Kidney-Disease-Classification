# %%
d = {"key":"val","key1":"val1"}

# %%
d['key1']
# Out:
# 'val1'

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 from box import ConfigBox, BoxValueError
#
# ModuleNotFoundError: No module named 'box'

# %%
from box import ConfigBox

# %%
d2 = ConfigBox({"key":"val","key1":"val1"})

# %%
d2.key
# Out:
# 'val'

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
type(d2)
# Out:
# box.config_box.ConfigBox

# %%
def get_prodict(x:int, y:int)-> int:
    return x*y

# %%
get_prodict(2,3)
# Out:
# 6

# %%
def get_add(x:int , y:int) ->int:
    return x+y

# %%
get_add(5,5)
# Out:
# 10
